# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from funpymodeling.exploratory import freq_tbl

# %%
data = pd.read_csv('Datos_Limpios_Mexico.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    26582 non-null  int64
#  1   name                                          26582 non-null  object
#  2   description                                   26582 non-null  object
#  3   neighborhood_overview                         26582 non-null  object
#  4   host_name                                     26582 non-null  object
#  5   host_location                                 26582 non-null  object
#  6   host_response_time                            26582 non-null  object
#  7   host_is_superhost                             26582 non-null  object
#  8   host_neighbourhood                            26582 non-null  object
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                                              name  \
# 0           0                                       Villa Dante
# 1           1                                      Condesa Haus
# 2           2                 2 bedroom apt. deco bldg, Condesa
# 3           3  Beautiful light Studio Coyoacan- full equipped !
# 4           4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...      Dici
# 1                                    Sin descripción  Fernando
# 2                                    Sin descripción  Nicholas
# ...

# %% [markdown]
# **EXTRACCIÓN DE CARACTERÍSTICAS A PARTIR DE APLICAR UN ANÁLISIS UNIDERIVADO A DIFERENTES VARIABLES CATEGÓRICAS**

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_name'])

#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 100]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_name')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('Nombre más comunes de los host')
plt.xlabel('host_name')
plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico de pastel de dataframe filtrado 
# filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_location'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 20]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_location')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Ubicaciones más comunes de los host')
# plt.xlabel('host_location')
# plt.ylabel('Frecuencia')

#Realizamos grafico de dispersion del dataframe filtrado
tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico de pastel de dataframe filtrado 
# filtro_index["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_response_time'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 1]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_response_time')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('tiempos de respuesta más comunes de los host')
# plt.xlabel('host_location')
# plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

#Realizamos grafico de aréa de dataframe filtrado
filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='host_response_time'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_is_superhost'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 1]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_is_superhost')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Superhost')
# plt.xlabel('host_is_superhost')
# plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['room_type'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 1]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('room_type')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('tipo de habitación')
plt.xlabel('room_type')
plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_neighbourhood'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_neighbourhood')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Superhost')
# plt.xlabel('host_is_superhost')
# plt.ylabel('Frecuencia')

#Realizamos grafico de dispersion del dataframe filtrado
tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['instant_bookable'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('instant_bookable')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Superhost')
# plt.xlabel('instant_bookable')
# plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

#Realizamos grafico de aréa de dataframe filtrado
filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='instant_bookable'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['last_review'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('last_review')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Superhost')
# plt.xlabel('host_is_superhost')
# plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['first_review'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 50]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('first_review')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('Primeras reseñas')
plt.xlabel('first_review')
plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['has_availability'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('has_availability')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Superhost')
# plt.xlabel('host_is_superhost')
# plt.ylabel('Frecuencia')

#Realizamos grafico de dispersion del dataframe filtrado
tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['amenities'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 40]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('amenities')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Superhost')
# plt.xlabel('host_is_superhost')
# plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

#Realizamos grafico de aréa de dataframe filtrado
filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='amenities'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['property_type'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 1]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('property_type')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('Superhost')
# plt.xlabel('host_is_superhost')
# plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['neighbourhood_cleansed'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('neighbourhood_cleansed')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('neighbourhood_cleansed')
plt.xlabel('neighbourhood_cleansed')
plt.ylabel('Frecuencia')

# #Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **CATEGORIZAR VARIABLES APLICANDO LA REGLA DE STURGES Y DESPLEGAR EN UN GRAFICO LAS FRECUENCIAS DE LAS CATEGORÍAS OBTENIDAS**

# %% [markdown]
# **host_response_rate**

# %%
data['host_response_rate'].info()
# n = len(data['host_response_rate'].unique())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      category
# dtypes: category(1)
# memory usage: 26.4 KB

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_response_rate'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 1]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_response_rate')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('host_response_rate')
# plt.xlabel('host_response_rate')
# plt.ylabel('Frecuencia')

#Realizamos grafico de dispersion del dataframe filtrado
tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Max = data['host_acceptance_rate'].max()
Min = data['host_acceptance_rate'].min()
Limites = [Min, Max]
Limites
# Out:
# ['Categorias1', 'Categorias8']

# %% [markdown]
# **host_total_listings_count**

# %%
data['host_total_listings_count'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
n = 26582

Max = data['host_total_listings_count'].max()
Min = data['host_total_listings_count'].min()
Limites = [Min, Max]
Limites
# Out:
# [1.0, 550.0]

# %%
#Calculamos el rango R
R = Max - Min
R
# Out:
# 549.0

# %%
#Calculamos el numero de los intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 15.689631010177528

# %%
#Calculamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 34.991262678126425

# %%
#categorizacion de variables
intervalos = np.linspace(1.0, 550, 9)
intervalos
# Out:
# array([  1.   ,  69.625, 138.25 , 206.875, 275.5  , 344.125, 412.75 ,
#        481.375, 550.   ])

# %%
#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"]

# %%
#Finalmente creamos las categorias en la columna numerica 
data['host_total_listings_count'] = pd.cut(x = data['host_total_listings_count'] , bins=intervalos, labels=categorias )
data['host_total_listings_count']
# Out:
# 0                NaN
# 1        Categorias1
# 2        Categorias1
# 3        Categorias1
# 4        Categorias1
#             ...
# 26577    Categorias5
# 26578    Categorias1
# 26579    Categorias1
# 26580    Categorias1
# 26581    Categorias1
# Name: host_total_listings_count, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_total_listings_count'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_total_listings_count')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('host_total_listings_count')
plt.xlabel('host_total_listings_count')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **host_acceptance_rate**

# %%
n = len(data['host_acceptance_rate'].unique())

# %%
Max = data['host_acceptance_rate'].max()
Min = data['host_acceptance_rate'].min()
Limites = [Min, Max]
Limites
# Out:
# [24.0, 100.0]

# %%
#Calculamos el rango R
R = Max - Min
R
# Out:
# 76.0

# %%
#Calculamos el numero de los intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni
# Out:
# 7.281754080932394

# %%
#Calculamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 10.437045683677985

# %%
#categorizacion de variables
intervalos = np.linspace(24.0, 100.0, 9)
intervalos
# Out:
# array([ 24. ,  33.5,  43. ,  52.5,  62. ,  71.5,  81. ,  90.5, 100. ])

# %%
#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"
]

# %%
#Finalmente creamos las categorias en la columna numerica 
data['host_acceptance_rate'] = pd.cut(x = data['host_acceptance_rate'] , bins=intervalos, labels=categorias )
data['host_acceptance_rate']
# Out:
# 0        Categorias8
# 1        Categorias8
# 2        Categorias4
# 3        Categorias8
# 4        Categorias8
#             ...
# 26577    Categorias8
# 26578    Categorias8
# 26579    Categorias8
# 26580    Categorias8
# 26581    Categorias8
# Name: host_acceptance_rate, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['host_acceptance_rate'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('host_acceptance_rate')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('host_acceptance_rate')
plt.xlabel('host_acceptance_rate')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **accommodates**|

# %%
data['accommodates'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
n = 26582

#Obtenemos el limite superior y limite inferior de la columna objetivo
Max = data['accommodates'].max()
Min = data['accommodates'].min()
Limites = [Min, Max]
Limites
# Out:
# [1.0, 10.0]

# %%
#Calculamos el rango R
R = Max - Min
R

#Calculamos el numero de los intervalos de clase "ni", aplicando la regla de Sturges
ni = 1+3.32*np.log10(n)
ni

#Calculamos el ancho del intervalo "i"
i = R/ni
i
# Out:
# 0.5736272570184661

# %%
#categorizacion de variables
intervalos = np.linspace(1.0, 10.0, 9)

#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"
]

#Finalmente creamos las categorias en la columna numerica 
data['accommodates'] = pd.cut(x = data['accommodates'], bins=intervalos, labels=categorias )
data['accommodates']
# Out:
# 0        Categorias1
# 1        Categorias2
# 2        Categorias3
# 3        Categorias1
# 4        Categorias1
#             ...
# 26577    Categorias3
# 26578    Categorias1
# 26579    Categorias1
# 26580    Categorias1
# 26581    Categorias1
# Name: accommodates, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['accommodates'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('accommodates')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('accommodates')
plt.xlabel('accommodates')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **bathrooms_text**

# %%
data['bathrooms_text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  object
# dtypes: object(1)
# memory usage: 207.8+ KB

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['bathrooms_text'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('bathrooms_text')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('host_response_rate')
plt.xlabel('host_response_rate')
plt.ylabel('Frecuencia')

# # Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **beds**

# %%
data['beds'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 13310 non-null  category
# dtypes: category(1)
# memory usage: 26.4 KB

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['beds'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('beds')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('beds')
plt.xlabel('beds')
plt.ylabel('Frecuencia')

# # Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **price**

# %%
data['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
n = 26582

Max = data['price'].max()
Min = data['price'].min()
Limites = [Min, Max]
Limites
# Out:
# [0.0, 15726.0]

# %%
#categorizacion de variables
intervalos = np.linspace(0.0, 15765.0, 9)
intervalos

#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"
]

#Finalmente creamos las categorias en la columna numerica 
data['price'] = pd.cut(x = data['price'], bins=intervalos, labels=categorias )
data['price']
# Out:
# 0        Categorias2
# 1        Categorias1
# 2        Categorias2
# 3        Categorias1
# 4        Categorias2
#             ...
# 26577    Categorias1
# 26578    Categorias2
# 26579    Categorias2
# 26580    Categorias2
# 26581    Categorias1
# Name: price, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['price'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('price')
filtro_index

#realizamos grafico de barras del dataframe filtrado 
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('beds')
plt.xlabel('beds')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **availability_365**

# %%
data['availability_365'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  int64
# dtypes: int64(1)
# memory usage: 207.8 KB

# %%
n = 26582

Max = data['availability_365'].max()
Min = data['availability_365'].min()
Limites = [Min, Max]
Limites
# Out:
# [0, 365]

# %%
#categorizacion de variables
intervalos = np.linspace(0, 365, 9)
intervalos

#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"
]

#Finalmente creamos las categorias en la columna numerica 
data['availability_365'] = pd.cut(x = data['availability_365'], bins=intervalos, labels=categorias )
data['availability_365']
# Out:
# 0        Categorias8
# 1        Categorias8
# 2        Categorias8
# 3        Categorias6
# 4        Categorias7
#             ...
# 26577    Categorias8
# 26578    Categorias4
# 26579    Categorias4
# 26580    Categorias4
# 26581    Categorias4
# Name: availability_365, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['beds'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('beds')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('beds')
# plt.xlabel('beds')
# plt.ylabel('Frecuencia')

# # Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **number_of_reviews**

# %%
data['number_of_reviews'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
n = 26582

Max = data['number_of_reviews'].max()
Min = data['number_of_reviews'].min()
Limites = [Min, Max]
Limites
# Out:
# [0.0, 271.0]

# %%
#categorizacion de variables
intervalos = np.linspace(0.0, 271.0, 9)
intervalos

#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"
]
#Finalmente creamos las categorias en la columna numerica 
data['number_of_reviews'] = pd.cut(x = data['number_of_reviews'], bins=intervalos, labels=categorias )
data['number_of_reviews']
# Out:
# 0                NaN
# 1        Categorias2
# 2        Categorias2
# 3        Categorias4
# 4        Categorias1
#             ...
# 26577            NaN
# 26578            NaN
# 26579            NaN
# 26580            NaN
# 26581            NaN
# Name: number_of_reviews, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['number_of_reviews'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('number_of_reviews')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('beds')
# plt.xlabel('beds')
# plt.ylabel('Frecuencia')

# # Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

# #Realizamos grafico de aréa de dataframe filtrado
# filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **review_scores_location**

# %%
data['review_scores_location'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
n = 26582

Max = data['review_scores_location'].max()
Min = data['review_scores_location'].min()
Limites = [Min, Max]
Limites
# Out:
# [4.03, 5.0]

# %%
#categorizacion de variables
intervalos = np.linspace(4.03, 5.0, 9)
intervalos

#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"
]
#Finalmente creamos las categorias en la columna numerica 
data['review_scores_location'] = pd.cut(x = data['review_scores_location'], bins=intervalos, labels=categorias )
data['review_scores_location']
# Out:
# 0        Categorias7
# 1        Categorias8
# 2        Categorias8
# 3        Categorias8
# 4        Categorias8
#             ...
# 26577    Categorias7
# 26578    Categorias7
# 26579    Categorias7
# 26580    Categorias7
# 26581    Categorias7
# Name: review_scores_location, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['review_scores_location'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('review_scores_location')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('beds')
# plt.xlabel('beds')
# plt.ylabel('Frecuencia')

# # Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

#Realizamos grafico de aréa de dataframe filtrado
filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

# #Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='review_scores_location'>

# %% [markdown]
# **review_scores_value**

# %%
data['review_scores_value'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
n = 26582

Max = data['review_scores_value'].max()
Min = data['review_scores_value'].min()
Limites = [Min, Max]
Limites
# Out:
# [3.69, 5.0]

# %%
#categorizacion de variables
intervalos = np.linspace(3.69, 5.0, 9)
intervalos

#Creamos las categorias 
categorias = ["Categorias1", "Categorias2", "Categorias3", "Categorias4",
              "Categorias5", "Categorias6", "Categorias7", "Categorias8"
]
#Finalmente creamos las categorias en la columna numerica 
data['review_scores_value'] = pd.cut(x = data['review_scores_value'], bins=intervalos, labels=categorias )
data['review_scores_value']
# Out:
# 0        Categorias7
# 1        Categorias5
# 2        Categorias8
# 3        Categorias8
# 4        Categorias7
#             ...
# 26577    Categorias7
# 26578    Categorias7
# 26579    Categorias7
# 26580    Categorias7
# 26581    Categorias7
# Name: review_scores_value, Length: 26582, dtype: category
# Categories (8, object): ['Categorias1' < 'Categorias2' < 'Categorias3' < 'Categorias4' < 'Categorias5' < 'Categorias6' < 'Categorias7' < 'Categorias8']

# %%
#Análisi a una variable en especifico
tabla1= freq_tbl(data['review_scores_value'])
tabla1
#Elimino las coluamnas 'percentage' y 'cumulative_perc' para trabajar con las frecuencias
tabla2 = tabla1.drop(['percentage', 'cumulative_perc'], axis=1)
tabla2

#Obtengo un filtro de los valores más relevantes de las variables categorica seleccionada 
filtro = tabla2[tabla2['frequency'] > 10]
filtro
#Ajusto el index de mi dataframe
filtro_index = filtro.set_index('review_scores_value')
filtro_index

# #realizamos grafico de barras del dataframe filtrado 
# filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
# plt.title('beds')
# plt.xlabel('beds')
# plt.ylabel('Frecuencia')

# # Realizamos grafico de dispersion del dataframe filtrado
# tabla1.plot("frequency", "cumulative_perc", kind="scatter")

#Realizamos grafico de aréa de dataframe filtrado
filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5)

#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
# tabla1.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='review_scores_value'>
